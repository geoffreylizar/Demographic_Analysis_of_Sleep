# %% [markdown]
# # Who Loses the Most Sleep? A Demographic Analysis of Poor Sleepers

# %% [markdown]
# <a id='research_question'></a>
# # Research Question

# %% [markdown]
# What demographic groups in the United States have been losing the most sleep over the last decade?

# %% [markdown]
# <a id='background'></a>
#
# ## Background & Prior Work

# %% [markdown]
# Many demographic groups have been critically underserved by society at large, both recently and historically; African Americans are commonly dismissed by doctors, who systematically prescribe them fewer painkillers—and at lower doses—for conditions that would otherwise merit such intervention [1]; even as of 2020, women still only make an average of 81 cents for every dollar their male colleagues make [2]; until unsettlingly recently, the law did not provide the LGBTQ+ community equal protection under the law [3]; and even breaking things down by age offers no relief, with Millennials (and now Gen Z) graduating into the worst economy the world has seen since the great depression [4]. With so many demographic groups suffering unequally in so many ways, it can be hard to know where to focus.
#
# The science of sleep is complex and involves as many as ten main structures of the brain [5]. It therefore comes as no surprise that sleep quality, quantity, and routine are affected by just about any stressor ranging from lifestyle and health factors (e.g., diet, exercise, and mental health), to personal and socio-demographic factors (e.g., financial concerns), to psychosocial and occupational factors (e.g., lack of choice or commuting) [6]. Clearly, the causes of sleep deprivation are diverse and often inscrutable [7], and with stress in America at an all-time high in 2020 [8], we think that investigating which subgroups of America have been losing the most sleep in the last decade could open the door to future analyses that explore which factors contribute the most to Americans getting worse sleep over time.
#
# **References:**
# 1. **Association of American Medical Colleges:** <u>How we fail black patients in pain</u> https://www.aamc.org/news-insights/how-we-fail-black-patients-pain
# 2. **PayScale:** <u>The State of the Gender Pay Gap 2020</u> https://www.payscale.com/data/gender-pay-gap
# 3. **MetroWeekly:** <u>President Biden issues executive order protecting LGBTQ people from discrimination</u> https://www.metroweekly.com/2021/01/president-biden-issues-executive-order-protecting-lgbtq-people-from-discrimination/
# 4. **Washington Post:** <u>The unluckiest generation in U.S. history</u> https://www.washingtonpost.com/business/2020/05/27/millennial-recession-covid/
# 5. **National Institute of Neurological Disorders and Stroke:**: <u>Brain Basics: Understanding Sleep</u> https://www.ninds.nih.gov/Disorders/Patient-Caregiver-Education/Understanding-sleep
# 6. **RAND Corporation** <u>Why sleep matters — the economic costs of insufficient sleep</u> https://www.rand.org/pubs/research_reports/RR1791.html
# 7. **American Psychological Association:** <u>Factors that contribute to insomnia</u> https://www.apa.org/monitor/oct01/insomnia#:~:text=Extended%20time%20in%20bed%2C%20napping,or%20a%20poor%20sleeping%20surface
# 8. **American Psychological Association:** <u>Stress in America<sup>TM</sup> 2020</u> https://www.apa.org/news/press/releases/stress/2020/report#:~:text=The%20COVID%2D19%20pandemic%20has,be%20serious%20and%20long%2Dlasting
# 9. **International Journal of Health Service** <u>Sexism and Racism in the American Health Care Industry: A Comparative Analysis</u> https://journals.sagepub.com/doi/10.2190/AK0C-M9JF-1TR1-5UYF
# 10. **Pew Research** <u>The Changing Profile of Unmarried Parents</u> https://www.pewsocialtrends.org/2018/04/25/the-changing-profile-of-unmarried-parents/#:~:text=This%20trend%20has%20boosted%20the,as%20were%2088%25%20in%201968.
# 11. **Pew Research** <u>6 facts about economic inequality in the U.S.</u> https://www.pewresearch.org/fact-tank/2020/02/07/6-facts-about-economic-inequality-in-the-u-s/#:~:text=2Income%20inequality%20in%20the,for%20Economic%20Cooperation%20and%20Development.&text=In%202017%2C%20the%20U.S.%20had%20a%20Gini%20coefficient%20of%200.434.
# 12. **National Geographic** <u>Our nights are getting brighter, and Earth is paying the price</u> https://www.nationalgeographic.com/science/2019/04/nights-are-getting-brighter-earth-paying-the-price-light-pollution-dark-skies/#:~:text=Another%20study%20from%202017%20suggests,rural%20road%2090%20miles%20away.
# 13. **Southern Medical Journal** <u>Noise Pollution: A Modern Plague</u> https://www.medscape.com/viewarticle/554566_2

# %% [markdown]
# # Hypothesis

# %% [markdown]
# Given the complicated and multi-dimensional nature of demographic splits, our hypothesis is similarly split into several dimensions:
# * **Anyone who the medical community critically underserves:** African Americans [1] and women in general [9] face systemic discrimination in the medical system, resulting from unconscious bias reinforced in doctors during their training. It is possible that this has led to worse sleep over time.
# * **Women:** There are several factors that contribute to our hypothesis that women have been losing more sleep than men. As mentioned, women are one demographic group that is underserved by the medical community. In addition, women are far more likely than men to be solo parents [10]
# * **Demographics with low Socioeconomic Status (SES):** It is well established that those in poverty are more sleep-deprived on average [6]. With income inequality at an all-time high (and still climbing) [11], we hypothesize that this increase will have led to an increase in sleep deprivation.
# * **Young people:** With income inequality hitting young people the worst [11], we hypothesize that similar factors will impact this demographic in an exaggerated fashion.
# * **People who live in metropolitan areas:** Though industrialization and large cities are by no means new phenomena, the rates of light [12] and noise [13] pollution have continued to rise over time. We hypothesize that these factors may have led to an increase in sleep deprivation in metropolitan areas.

# %% [markdown]
# # Dataset(s)

# %% [markdown]
# * Dataset Name: Percent of Adults Who Get Sufficient Sleep by Year by State (NHIS_2013_%ofAdultsWhoGetSufficientSleep_byYear_byState.xlsx)
# * Link to the dataset: https://www.healthypeople.gov/2020/data-search/Search-the-Data#objid=5261
# * Number of observations: Undisclosed (see below); pending data request from CDC
#
# This dataset was collected by the Center of Disease Control (CDC) through their yearly National Health Interview Survey, which collects information on the health of the civilian, noninstitutionalized population of the United States. This particular dataset includes survey information from the years 2008–2018 to calculate the percentage of the adult population that self-report getting a sufficient amount of sleep, which the CDC defines as an average of at least 7 hours of sleep per night. Demographic data is also collected for each participant, allowing the NHIS to break down the adult population into smaller, more detailed categories so the kinds of demographic analyses like the one our question is asking can be performed.
#
# The biggest weakness in our dataset is that the total population of the participants of the survey are not included in this set, and the results are strictly defined by percentages. We don’t know how many people participated, nor do we have a count of participants per category; we will have to use variability in the data as our metric for deciding which groups may not have had statistically significant sample sizes. While this methodology is far from perfect, it is the best we can do with the existing data. Our best metric of variability is likely to be a combination of yearly standard error and year-to-year variance; too much of each is a likely indicator of an insufficient sample size.
#
# It is also worth noting that the original spreadsheet only contains state-by-state data for 2013. We will therefore be limited to analyzing national-level data over time.

# %% [markdown]
# # Setup

# %%
# Importing numpy, pandas, seaborn, and matplotlib, then setting our general graphing parameters
import numpy as np
import pandas as pd
import seaborn as sns
import patsy
import statsmodels.api as sm
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
params = {'figure.figsize': (17, 7),
          'legend.fontsize': 17,
          'figure.titlesize': 40,
         'axes.labelsize': 20,
         'axes.titlesize': 20,
         'xtick.labelsize': 20,
         'ytick.labelsize': 20}
pylab.rcParams.update(params)
sns.set(font_scale = 1.5, style = "white")

# %%
# Read in the original ("unclean") csv
unclean = pd.read_csv('Data/NHIS_2013_%ofAdultsWhoGetSufficientSleep_byYear_byState.csv', header = 1, index_col = 0)
unclean.head()
# Out:
#                     Geography Estimate  StdErr  LowerCI  UpperCI Estimate.1  \
# PopTitle
# Total           United States     71.6   0.414     70.7     72.4       71.6
# Sex                       NaN      NaN     NaN      NaN      NaN        NaN
#    Male         United States     71.4   0.588     70.2     72.5       71.5
#    Female       United States     71.7   0.519     70.7     72.8       71.7
# Race/Ethnicity            NaN      NaN     NaN      NaN      NaN        NaN
#
#                 StdErr.1  LowerCI.1  UpperCI.1 Estimate.2  ...  LowerCI.8  \
# PopTitle                                                   ...
# Total              0.372       70.8       72.3       71.3  ...       67.1
# Sex                  NaN        NaN        NaN        NaN  ...        NaN
#    Male            0.529       70.4       72.5         72  ...       67.2
#    Female          0.497       70.7       72.6       70.6  ...       66.5
# ...

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Cleaning 1
# Our goal is to only analyze the Estimate for each year. However, StdErr will be a good measure of variance. When the data cleaning is finished, we should end up with two dataframes: one for the estimates, and one for the StdErr.

# %%
# Create a list of columns to drop, starting with 'Geography'
to_drop = ['Geography']
for header in unclean.columns:
    if 'erC' in header:
        to_drop.append(header)

# Drop the columns we don't want
unclean = unclean.drop(columns = to_drop)
unclean.head()
# Out:
#                Estimate  StdErr Estimate.1  StdErr.1 Estimate.2  StdErr.2  \
# PopTitle
# Total              71.6   0.414       71.6     0.372       71.3     0.345
# Sex                 NaN     NaN        NaN       NaN        NaN       NaN
#    Male            71.4   0.588       71.5     0.529         72     0.494
#    Female          71.7   0.519       71.7     0.497       70.6     0.459
# Race/Ethnicity      NaN     NaN        NaN       NaN        NaN       NaN
#
#                 Estimate.3  StdErr.3  Estimate.4  StdErr.4  ...  Estimate.6  \
# PopTitle                                                    ...
# Total                 71.0     0.333        70.8     0.334  ...        69.3
# Sex                    NaN       NaN         NaN       NaN  ...         NaN
#    Male               70.7     0.483        71.2     0.479  ...        69.4
#    Female             71.4     0.436        70.4     0.457  ...        69.2
# ...

# %% [markdown]
# ### Cleaning 2
# There are also indices like 'Sex' that are general categories, not specific demographics. These do not contain data and are thus not relevant to our analysis. Because these are the only completely empty rows, we can use .dropna() to get rid of them

# %%
unclean = unclean.dropna(how = 'all')
unclean.head()
# Out:
#                                          Estimate  StdErr Estimate.1  \
# PopTitle
# Total                                        71.6   0.414       71.6
#    Male                                      71.4   0.588       71.5
#    Female                                    71.7   0.519       71.7
#    American Indian or Alaska Native only     74.4   3.811       71.7
#    Asian only                                72.1   1.587       69.9
#
#                                           StdErr.1 Estimate.2  StdErr.2  \
# PopTitle
# Total                                        0.372       71.3     0.345
#    Male                                      0.529         72     0.494
#    Female                                    0.497       70.6     0.459
#    American Indian or Alaska Native only     3.948       63.5     4.609
#    Asian only                                1.520       69.3     1.383
#
#                                           Estimate.3  StdErr.3  Estimate.4  \
# PopTitle
# ...

# %% [markdown]
# ### Cleaning 3
# Before we separate our data into Estimate and StdErr values, we need to establish some dictionaries to help us with the renaming steps.

# %%
# New index names for our main dataframe
est_index = {'Estimate': 2008, 'Estimate.1': 2009, 'Estimate.2': 2010, 'Estimate.3': 2011, 
            'Estimate.4': 2012, 'Estimate.5': 2013, 'Estimate.6': 2014, 'Estimate.7': 2015, 
            'Estimate.8': 2016, 'Estimate.9': 2017, 'Estimate.10': 2018}

# New index names for the dataframe of standard error values
std_err_index = {'StdErr': 2008, 'StdErr.1': 2009, 'StdErr.2': 2010, 'StdErr.3': 2011, 
            'StdErr.4': 2012, 'StdErr.5': 2013, 'StdErr.6': 2014, 'StdErr.7': 2015, 
            'StdErr.8': 2016, 'StdErr.9': 2017, 'StdErr.10': 2018}


# The category names they used are not programming-friendly.
# These are what will become new column names for our two dataframes
new_cols = {'Total': 'Total', '   Male': 'Male', '   Female': 'Female', 
            '   American Indian or Alaska Native only': 'Native', '   Asian only': 'Asian', 
            '   Native Hawaiian or Other Pacific Islander only': 'Hawaiian_or_PI', 
            '   Black or African American only': 'Afr_Amer', '   White only': 'White', 
            '   2 or more races': '2_or_more', '   Hispanic or Latino': 'Hispanic', 
            '   Not Hispanic or Latino': 'Not_Hispanic', 
            '      Black or African American only, not Hispanic or Latino': 'Afr_Amer_not_Hispanic', 
            '      White only, not Hispanic or Latino': 'White_not_Hispanic', '   18-44 years': '18_to_44', 
            '      18-24 years': '18_to_24', '      25-44 years': '25_to_44', '   45-64 years': '45_to_64', 
            '      45-54 years': '45_to_54', '      55-64 years': '55_to_64', '   65 years and over': '65_Plus', 
            '      65-74 years': '65_to_74', '      75-84 years': '75_to_84', '      85 years and over': '85_Plus', 
            '   < High school': 'Below_HS', '   High school': 'HS', '   Some college': 'Some_college', 
            '   Associates degree': 'AA_AS', '   4-year college degree': 'BA_BS', 
            '   Advanced degree': 'MA_MS_Plus', '   <100': 'Below_100K', '   100-199': '100_to_199K', 
            '   200-399': '200_to_399K', '   400-599': '400_to_599K', '   600+': '600K_Plus', 
            '   Single': 'Single_Not_Parent', '   Single parent with children': 'Single_Parent', 
            '   Married couple or partners': 'Two_Adults', '   Two parent family with children': 'Two_Parent_Family', 
            '   Other': 'Other_House', '   US': 'In_US', '   Outside US': 'Outside_US', 
            '   People with disabilities': 'Disabled', '   People without disabilities': 'Not_Disabled', 
            '   Metropolitan': 'Metro', '   Non-metropolitan': 'Not_Metro', '   Insured': 'Insured', 
            '      Private': 'Private_Ins', '   Uninsured': 'Uninsured', '      Public': 'Public_Ins', 
            '   Straight': 'Straight', '      Straight, Male': 'Straight_Male', '   Gay/Lesbian': 'Gay_Les', 
            '   Bisexual': 'Bi', '      Straight, Female': 'Straight_Female', '      Gay, Male': 'Gay_Male', 
            '      Gay/Lesbian, Female': 'Gay_Female', '      Bisexual, Male': 'Bi_Male', 
            '      Bisexual, Female': 'Bi_Female', '   Married': 'Married', '   Cohabiting partner': 'Unmarried_Couple', 
            '   Divorced or separated': 'Divorced', '   Widowed': 'Widow', '   Never married': 'Never_married'}

# %% [markdown]
# ### Cleaning 4
# Now it's time to separate our two sets of data (Estimate vs StdErr for each year) and rename our columns and indices.

# %%
# Create two lists of the columns so we can separate the Estimates and StdErr
estimate = [] # List of columns to drop for std_err_df
std_err = [] # List of columns to drop for df
for header in unclean.columns:
    if 'Est' in header:
        estimate.append(header)
    else:
        std_err.append(header)

# Now that we have our variables defined, we can create our two dataframes.        
df = unclean.drop(columns = std_err).rename(columns = est_index).transpose(copy = True)
std_err_df = unclean.drop(columns = estimate).rename(columns = std_err_index).transpose(copy = True)

# For the sake of conserving horizontal space, we rename the columns and index for our dataframes here
df = df.rename(columns = new_cols).rename_axis(columns = {'PopTitle': 'Year'})
std_err_df = std_err_df.rename(columns = new_cols).rename_axis(columns = {'PopTitle': 'Year'})

# %%
print('Data types in df:')
df.dtypes
# Out:
# Data types in df:
# Year
# Total               object
# Male                object
# Female              object
# Native              object
# Asian               object
#                      ...
# Married             object
# Unmarried_Couple    object
# Divorced            object
# Widow               object
# Never_married       object
# Length: 63, dtype: object

# %%
print('Data types in std_err_df:')
std_err_df.dtypes
# Out:
# Data types in std_err_df:
# Year
# Total               float64
# Male                float64
# Female              float64
# Native              float64
# Asian               float64
#                      ...
# Married             float64
# Unmarried_Couple    float64
# Divorced            float64
# Widow               float64
# Never_married       float64
# Length: 63, dtype: object

# %% [markdown]
# ### Cleaning 5
# We still have one problem: thanks to the original csv file having multiple ways of signaling null values, some of the values were turned into strings during the conversion. We can write a function to use with the .apply() method to convert everything to floats. As this only happened with df and not std_err_df, we only need to run this for df.

# %%
def change_dtypes(value):
    # These are the three ways the researchers indicated null values. Return np.nan for each
    if value in ['NaN', 'DSU', '---']:
        return np.nan
    else:
        return float(value)

# Apply the changes to each column
for column in df.columns:
    df[column] = df[column].apply(change_dtypes)

# Let's check again
print('Data types in df after reformatting:')
df.dtypes
# Out:
# Data types in df after reformatting:
# Year
# Total               float64
# Male                float64
# Female              float64
# Native              float64
# Asian               float64
#                      ...
# Married             float64
# Unmarried_Couple    float64
# Divorced            float64
# Widow               float64
# Never_married       float64
# Length: 63, dtype: object

# %% [markdown]
# ### Cleaning 6
# Now that we've finished cleaning the data, let's take a look at our new dataframes!

# %%
df
# Out:
# Year  Total  Male  Female  Native  Asian  Hawaiian_or_PI  Afr_Amer  White  \
# 2008   71.6  71.4    71.7    74.4   72.1             NaN      63.9   72.8
# 2009   71.6  71.5    71.7    71.7   69.9            53.6      63.5   73.0
# 2010   71.3  72.0    70.6    63.5   69.3             NaN      64.0   72.7
# 2011   71.0  70.7    71.4    67.5   72.0            54.9      62.6   72.4
# 2012   70.8  71.2    70.4    65.6   70.7            44.6      64.1   72.2
# 2013   69.2  69.1    69.3    64.1   69.9            49.2      60.2   70.7
# 2014   69.3  69.4    69.2    61.7   69.3            61.8      59.7   71.0
# 2015   68.1  68.6    67.6    63.3   68.8            66.4      58.5   69.8
# 2016   67.8  68.2    67.5    65.1   67.6            60.9      59.5   69.5
# 2017   67.5  67.7    67.2    66.9   66.8            74.2      60.0   68.9
# 2018   67.4  67.5    67.3    58.7   67.7            53.4      59.1   69.0
#
# Year  2_or_more  Hispanic  ...  Straight_Female  Gay_Male  Gay_Female  \
# ...

# %%
std_err_df
# Out:
# Year  Total   Male  Female  Native  Asian  Hawaiian_or_PI  Afr_Amer  White  \
# 2008  0.414  0.588   0.519   3.811  1.587             NaN     1.119  0.458
# 2009  0.372  0.529   0.497   3.948  1.520           9.139     1.006  0.425
# 2010  0.345  0.494   0.459   4.609  1.383             NaN     0.963  0.383
# 2011  0.333  0.483   0.436   2.796  1.211           9.134     0.902  0.372
# 2012  0.334  0.479   0.457   3.432  1.252           9.324     0.894  0.369
# 2013  0.350  0.488   0.477   3.810  1.258           8.716     0.942  0.391
# 2014  0.368  0.531   0.499   3.916  1.354           8.308     0.982  0.411
# 2015  0.375  0.549   0.498   3.742  1.384           7.259     1.029  0.413
# 2016  0.374  0.548   0.504   3.983  1.550           7.381     1.181  0.402
# 2017  0.389  0.565   0.538   3.885  1.674           7.869     1.261  0.418
# 2018  0.372  0.537   0.499   3.811  1.518           6.019     1.237  0.413
#
# ...

# %% [markdown]
# ### Cleaning 7
# The data is now relatively clean and prepared for analyzation. To streamline this process, we first section the dataframes into demographic categories in order to explore each group individually:

# %%
# Section df into dataframes of major demographic categories
gender = pd.DataFrame(data = {'Male': df['Male'], 'Female': df['Female']})

race = pd.DataFrame(data = {'Native': df['Native'], 
                            'Asian': df['Asian'], 
                            'Hawaiian_or_PI': df['Hawaiian_or_PI'], 
                            'Afr_Amer': df['Afr_Amer'], 
                            'White': df['White'], '2_or_more': df['2_or_more'], 
                            'Hispanic': df['Hispanic'], 
                            'Not_Hispanic': df['Not_Hispanic'], 
                            'Afr_Amer_not_Hispanic': df['Afr_Amer_not_Hispanic'], 
                            'White_not_Hispanic': df['White_not_Hispanic']})

age_general = pd.DataFrame(data = {'18_to_44': df['18_to_44'], 
                                   '45_to_64': df['45_to_64'], 
                                   '65_Plus': df['65_Plus']})

age_specific = pd.DataFrame(data = {'18_to_24': df['18_to_24'], 
                                    '25_to_44': df['25_to_44'], 
                                    '45_to_54': df['45_to_54'], 
                                    '55_to_64': df['55_to_64'], 
                                    '65_to_74': df['65_to_74'], 
                                    '75_to_84': df['75_to_84'], 
                                    '85_Plus': df['85_Plus']})

education = pd.DataFrame(data = {'Below_HS': df['Below_HS'], 
                                 'HS': df['HS'], 
                                 'Some_college': df['Some_college'], 
                                 'AA_AS': df['AA_AS'], 
                                 'BA_BS': df['BA_BS'], 
                                 'MA_MS_Plus': df['MA_MS_Plus']})

income = pd.DataFrame(data = {'Below_100K': df['Below_100K'], 
                              '100_to_199K': df['100_to_199K'], 
                              '200_to_399K': df['200_to_399K'], 
                              '400_to_599K': df['400_to_599K'], 
                              '600K_Plus': df['600K_Plus']})

household = pd.DataFrame(data = {'Single_Not_Parent': df['Single_Not_Parent'], 
                                 'Single_Parent': df['Single_Parent'], 
                                 'Two_Adults': df['Two_Adults'], 
                                 'Two_Parent_Family': df['Two_Parent_Family'], 
                                 'Other_House': df['Other_House']})

birth_country = pd.DataFrame(data = {'In_US': df['In_US'], 'Outside_US': df['Outside_US']})

disability = pd.DataFrame(data = {'Disabled': df['Disabled'], 'Not_Disabled': df['Not_Disabled']})

location = pd.DataFrame(data = {'Metro': df['Metro'], 'Not_Metro': df['Not_Metro']})

insurance = pd.DataFrame(data = {'Insured': df['Insured'], 
                                 'Private_Ins': df['Private_Ins'], 
                                 'Public_Ins': df['Public_Ins'], 
                                 'Uninsured': df['Uninsured']})

orientation = pd.DataFrame(data = {'Straight': df['Straight'], 
                                   'Straight_Male': df['Straight_Male'], 
                                   'Straight_Female': df['Straight_Female'], 
                                   'Gay_Les': df['Gay_Les'], 
                                   'Gay_Male': df['Gay_Male'], 
                                   'Gay_Female': df['Gay_Female'], 
                                   'Bi': df['Bi'], 
                                   'Bi_Male': df['Bi_Male'], 
                                   'Bi_Female': df['Bi_Female']})

marital_status = pd.DataFrame(data = {'Married': df['Married'], 
                                      'Unmarried_Couple': df['Unmarried_Couple'], 
                                      'Divorced': df['Divorced'], 
                                      'Widow': df['Widow'], 
                                      'Never_married': df['Never_married']})

# Preview a sectioned dataframe
race
# Out:
#       Native  Asian  Hawaiian_or_PI  Afr_Amer  White  2_or_more  Hispanic  \
# 2008    74.4   72.1             NaN      63.9   72.8       62.4      74.6
# 2009    71.7   69.9            53.6      63.5   73.0       66.7      74.2
# 2010    63.5   69.3             NaN      64.0   72.7       64.8      73.4
# 2011    67.5   72.0            54.9      62.6   72.4       65.0      73.0
# 2012    65.6   70.7            44.6      64.1   72.2       58.5      73.4
# 2013    64.1   69.9            49.2      60.2   70.7       62.1      70.9
# 2014    61.7   69.3            61.8      59.7   71.0       63.7      68.7
# 2015    63.3   68.8            66.4      58.5   69.8       58.7      68.9
# 2016    65.1   67.6            60.9      59.5   69.5       57.0      68.6
# 2017    66.9   66.8            74.2      60.0   68.9       60.8      67.3
# 2018    58.7   67.7            53.4      59.1   69.0       60.9      68.2
#
#       Not_Hispanic  Afr_Amer_not_Hispanic  White_not_Hispanic
# ...

# %%
# Section std_err_df into dataframes of major demographic categories
# Reuse code from previous section
std_err_gender = pd.DataFrame(data = {'Male': std_err_df['Male'], 'Female': std_err_df['Female']})

std_err_race = pd.DataFrame(data = {'Native': std_err_df['Native'], 
                                    'Asian': std_err_df['Asian'], 
                                    'Hawaiian_or_PI': std_err_df['Hawaiian_or_PI'], 
                                    'Afr_Amer': std_err_df['Afr_Amer'], 
                                    'White': std_err_df['White'], 
                                    '2_or_more': std_err_df['2_or_more'], 
                                    'Hispanic': std_err_df['Hispanic'], 
                                    'Not_Hispanic': std_err_df['Not_Hispanic'], 
                                    'Afr_Amer_not_Hispanic': std_err_df['Afr_Amer_not_Hispanic'], 
                                    'White_not_Hispanic': std_err_df['White_not_Hispanic']})

std_err_age_general = pd.DataFrame(data = {'18_to_44': std_err_df['18_to_44'], 
                                           '45_to_64': std_err_df['45_to_64'], 
                                           '65_Plus': std_err_df['65_Plus']})

std_err_age_specific = pd.DataFrame(data = {'18_to_24': std_err_df['18_to_24'], 
                                            '25_to_44': std_err_df['25_to_44'], 
                                            '45_to_54': std_err_df['45_to_54'], 
                                            '55_to_64': std_err_df['55_to_64'], 
                                            '65_to_74': std_err_df['65_to_74'], 
                                            '75_to_84': std_err_df['75_to_84'], 
                                            '85_Plus': std_err_df['85_Plus']})

std_err_education = pd.DataFrame(data = {'Below_HS': std_err_df['Below_HS'], 
                                         'HS': std_err_df['HS'], 
                                         'Some_college': std_err_df['Some_college'], 
                                         'AA_AS': std_err_df['AA_AS'], 
                                         'BA_BS': std_err_df['BA_BS'], 
                                         'MA_MS_Plus': std_err_df['MA_MS_Plus']})

std_err_income = pd.DataFrame(data = {'Below_100K': std_err_df['Below_100K'], 
                                      '100_to_199K': std_err_df['100_to_199K'], 
                                      '200_to_399K': std_err_df['200_to_399K'], 
                                      '400_to_599K': std_err_df['400_to_599K'], 
                                      '600K_Plus': std_err_df['600K_Plus']})

std_err_household = pd.DataFrame(data = {'Single_Not_Parent': std_err_df['Single_Not_Parent'], 
                                         'Single_Parent': std_err_df['Single_Parent'], 
                                         'Two_Adults': std_err_df['Two_Adults'], 
                                         'Two_Parent_Family': std_err_df['Two_Parent_Family'],
                                         'Other_House': std_err_df['Other_House']})

std_err_birth_country = pd.DataFrame(data = {'In_US': std_err_df['In_US'], 'Outside_US': std_err_df['Outside_US']})

std_err_disability = pd.DataFrame(data = {'Disabled': std_err_df['Disabled'], 'Not_Disabled': std_err_df['Not_Disabled']})

std_err_location = pd.DataFrame(data = {'Metro': std_err_df['Metro'], 'Not_Metro': std_err_df['Not_Metro']})

std_err_insurance = pd.DataFrame(data = {'Insured': std_err_df['Insured'], 
                                         'Private_Ins': std_err_df['Private_Ins'], 
                                         'Public_Ins': std_err_df['Public_Ins'], 
                                         'Uninsured': std_err_df['Uninsured']})

std_err_orientation = pd.DataFrame(data = {'Straight': std_err_df['Straight'], 
                                           'Straight_Male': std_err_df['Straight_Male'], 
                                           'Straight_Female': std_err_df['Straight_Female'], 
                                           'Gay_Les': std_err_df['Gay_Les'], 
                                           'Gay_Male': std_err_df['Gay_Male'], 
                                           'Gay_Female': std_err_df['Gay_Female'], 
                                           'Bi': std_err_df['Bi'], 
                                           'Bi_Male': std_err_df['Bi_Male'], 
                                           'Bi_Female': std_err_df['Bi_Female']})

std_err_marital_status = pd.DataFrame(data = {'Married': std_err_df['Married'], 
                                              'Unmarried_Couple': std_err_df['Unmarried_Couple'], 
                                              'Divorced': std_err_df['Divorced'], 
                                              'Widow': std_err_df['Widow'], 
                                              'Never_married': std_err_df['Never_married']})

# Preview a sectioned dataframe
std_err_race
# Out:
#       Native  Asian  Hawaiian_or_PI  Afr_Amer  White  2_or_more  Hispanic  \
# 2008   3.811  1.587             NaN     1.119  0.458      3.810     0.987
# 2009   3.948  1.520           9.139     1.006  0.425      3.267     0.853
# 2010   4.609  1.383             NaN     0.963  0.383      2.651     0.765
# 2011   2.796  1.211           9.134     0.902  0.372      2.343     0.748
# 2012   3.432  1.252           9.324     0.894  0.369      2.568     0.716
# 2013   3.810  1.258           8.716     0.942  0.391      2.631     0.793
# 2014   3.916  1.354           8.308     0.982  0.411      2.633     0.841
# 2015   3.742  1.384           7.259     1.029  0.413      2.873     0.838
# 2016   3.983  1.550           7.381     1.181  0.402      2.848     1.041
# 2017   3.885  1.674           7.869     1.261  0.418      2.710     1.122
# 2018   3.811  1.518           6.019     1.237  0.413      2.815     0.971
#
#       Not_Hispanic  Afr_Amer_not_Hispanic  White_not_Hispanic
# ...

# %% [markdown]
# # Data Analysis & Results (EDA)

# %% [markdown]
# ### EDA 1.0: Preliminary Analysis
# Here we preemptively identify any potential issues with our data. First, let's see what demographics are missing in each year.

# %%
# Create a dataframe that includes only demographics that are not missing information
no_nan_vals = df.dropna(how = 'any', axis = 1)

# Drop all columns from no_nan_vals, leaving only columns that are missing data
missing_df = df.drop(labels = no_nan_vals.columns, axis = 1)
missing_df
# Out:
# Year  Hawaiian_or_PI  Disabled  Not_Disabled  Straight  Straight_Male  \
# 2008             NaN       NaN           NaN       NaN            NaN
# 2009            53.6       NaN           NaN       NaN            NaN
# 2010             NaN      64.9          72.1       NaN            NaN
# 2011            54.9      65.6          72.4       NaN            NaN
# 2012            44.6      63.6          72.3       NaN            NaN
# 2013            49.2      65.3          71.0      69.2           69.1
# 2014            61.8      62.9          70.1      69.4           69.5
# 2015            66.4      64.5          68.9      68.3           68.8
# 2016            60.9      63.5          69.6      67.8           68.3
# 2017            74.2      63.6          69.3      67.6           67.7
# 2018            53.4       NaN           NaN      67.5           67.5
#
# Year  Gay_Les    Bi  Straight_Female  Gay_Male  Gay_Female  Bi_Male  Bi_Female
# ...

# %% [markdown]
# It looks like we're missing 2008 and 2010 data for the category of "Native Hawaiian or Other Pacific Islander only" (no clear reason for this is given on the site from which the data was downloaded). It also seems like disability information was not collected until 2010 (and was not collected in 2018), and that sexual orientation information was not collected until 2013. This will be good to keep in mind for our analysis.
#
# ### EDA 1.0.1
#
# Now that we have an idea of what values missing, we have to assess the reliability of data we do have. We don't have information about how many people were included in each category, so we have to find another way to narrow down which groups might have had sample sizes that make them statistically unreliable for drawing conclusions. Here, we calculate the grand mean (the mean of means) of the standard errors for each demographic category, and use this to gauge a  reasonable StdErr cutoff to determine which groups are "too variable to be reliable".

# %%
# Store average of each column from 'std_err_df' as a list
std_err_means_list = std_err_df.agg('mean').to_list()

# Calculate mean value of list of averages
mean_means = sum(std_err_means_list) / len(std_err_means_list)
print("Grand Mean Standard Error = ", mean_means)
# Out:
# Grand Mean Standard Error =  1.3244265993266

# %% [markdown]
# ### EDA 1.0.2
# Given our pooled mean of 1.324, we determine 2 to be our reasonable cutoff. Referencing our cutoff, we identify demographic categories that are highly variable:

# %%
# With an aggregate mean StdErr of 1.324, I think 2 is a reasonable cutoff for "too variable to be reliable"

# Store average of each column from 'std_err_df' as a dictionary
std_err_means_dict = std_err_df.agg('mean').to_dict()

# Initialize empty dictionary
std_err_issues = {}

# Iterate StdErr dictionary; add high variability groups to 'issues'
print("Groups with High Variability by Standard Error: ")
for item in std_err_means_dict:
    if std_err_means_dict[item] >= 2:
        std_err_issues[item] = std_err_means_dict[item]
        print('%-20s' '%s' % (item, round(std_err_issues[item], 4)))
# Out:
# Groups with High Variability by Standard Error:
# Native              3.7948
# Hawaiian_or_PI      8.1277
# 2_or_more           2.8317
# Gay_Les             2.8393
# Bi                  3.7727
# Gay_Male            3.807
# Gay_Female          4.0988
# Bi_Male             6.8075
# Bi_Female           4.3837

# %% [markdown]
# ### EDA 1.1.0
# Standard Error isn't our only possible measure of excessive variance. Another possible indicator of small sample size would be too much year-to-year variance, or what we will call the "Yearly Variance Magnitude" (YVM)

# %%
def yearly_variance_magnitude(df):
    # Get a list of the columns
    columns = df.columns.tolist()
    
    # Dictionary for storing our outputs
    temp_dict = {}
    
    # Iterate over columns to calculate the yvm for each
    for column in columns:
        year = 2008 # for the index
        total_magnitude = 0 # running total of magnitude
        divisor = 0
        
        # Iterate start year from 2008-2017
        while year < 2018:
            try:
                # If either value is NaN, skip it and don't increase the divisor for our mean
                int(df.loc[year][column])
                int(df.loc[year + 1][column])
                # Take the current year's value and subtract it from the next year's value
                #     Then add the absolute value to total_magnitude
                total_magnitude += abs(df.loc[year + 1][column] - df.loc[year][column])
                divisor += 1
                year += 1
            except:
                year += 1
                
        temp_dict[column] = np.round((total_magnitude / divisor), 3)
    
    # Sort the dictionary
    variance_dict = dict(sorted(temp_dict.items(), key=lambda item: item[1]))
    
    # A few analysis variables
    dict_keys = list(variance_dict.keys())
    variance_min = variance_dict[dict_keys[0]]
    variance_max = variance_dict[dict_keys[-1]]
    variance_mean = np.round((sum(variance_dict.values()) / len(variance_dict)), 3)
    variance_range = np.round((variance_max - variance_min), 3)
    print(' Min variance: ', variance_min, '\n', 'Max variance: ', variance_max, '\n', 
          'Average variance: ', variance_mean, '\n', 'Variance range: ', variance_range)
    
    return variance_dict

# %%
# Analysis time!
# ranges_dict = dict(sorted(yearly_variance_magnitude(df).items(), key=lambda item: item[1]))
print(' Statistical breakdown of YVM:')
variance_dict = yearly_variance_magnitude(df)

# Code to print them out neatly
print('')
keys = list(variance_dict.keys())
keys_small = keys[:21]
keys_medium = keys[21:42]
keys_large = keys[42:]
for a, b, c in zip(keys_small, keys_medium, keys_large):
    tab_a = '\t'
    tab_b = '\t'
    tab_c = '\t'
    if len(a) < 7:
        tab_a = '\t\t\t'
    elif len(a) < 14:
        tab_a = '\t\t'
    if len(b) < 6:
        tab_b = '\t\t\t'
    elif len(b) < 14:
        tab_b = '\t\t'
    if len(c) < 6:
        tab_c = '\t\t\t'
    elif len(c) < 14:
        tab_c = '\t\t'
    print(a, tab_a, variance_dict[a], '\t', b, tab_b, variance_dict[b], '\t', c, tab_c, variance_dict[c])
# Out:
#  Statistical breakdown of YVM:
#  Min variance:  0.42
#  Max variance:  12.06
#  Average variance:  1.728
#  Variance range:  11.64
#
# Straight 		 0.42 	 Private_Ins 		 0.7 	 75_to_84 		 1.38
# Total 			 0.44 	 Single_Not_Parent 	 0.71 	 Below_HS 		 1.39
# Straight_Female 	 0.44 	 18_to_44 		 0.77 	 Below_100K 		 1.41
# Metro 			 0.45 	 Widow 			 0.77 	 MA_MS_Plus 		 1.44
# In_US 			 0.47 	 600K_Plus 		 0.78 	 Outside_US 		 1.44
# Straight_Male 		 0.48 	 Two_Adults 		 0.79 	 Uninsured 		 1.55
# Not_Hispanic 		 0.49 	 45_to_54 		 0.84 	 Public_Ins 		 1.56
# White 			 0.5 	 Two_Parent_Family 	 0.84 	 18_to_24 		 1.61
# 65_Plus 		 0.51 	 BA_BS 			 0.88 	 AA_AS 			 1.73
# Insured 		 0.53 	 Not_Metro 		 0.9 	 Unmarried_Couple 	 2.1
# White_not_Hispanic 	 0.55 	 Divorced 		 0.9 	 Single_Parent 		 2.12
# 45_to_64 		 0.57 	 65_to_74 		 0.93 	 85_Plus 		 2.2
# 400_to_599K 		 0.57 	 Hispanic 		 0.94 	 2_or_more 		 2.87
# Married 		 0.57 	 100_to_199K 		 0.96 	 Native 		 3.41
# ...

# %% [markdown]
# ### EDA 1.1.1
# We have some clear outliers here. Let's see if they're the same ones as before.

# %%
print('Groups from previous metric of variance: ')
new_issues = []
watch_these = []
for group in variance_dict:
    if len(group) < 7:
        tab = '\t\t'
    else:
        tab = '\t'
    if group in std_err_issues:
        watch_these.append(group)
        print(group,  tab + 'StdErr: ', np.round(std_err_means_dict[group], 3), 
              '\t YVM: ', variance_dict[group])
    # Lowest potential outlier YVM in std_err_issues
    elif variance_dict[group] >= 2.87:
        new_issues.append(group)
        watch_these.append(group)
print('\nPotential new issues: ')
for group in new_issues:
    print(group, tab + ' StdErr: ', np.round(std_err_means_dict[group], 3), 
          ' YVM: ', variance_dict[group])
if len(new_issues) == 0:
    print('None')
# Out:
# Groups from previous metric of variance:
# 2_or_more 	StdErr:  2.832 	 YVM:  2.87
# Native 		StdErr:  3.795 	 YVM:  3.41
# Gay_Les 	StdErr:  2.839 	 YVM:  3.8
# Gay_Male 	StdErr:  3.807 	 YVM:  4.68
# Gay_Female 	StdErr:  4.099 	 YVM:  4.72
# Bi 		StdErr:  3.773 	 YVM:  5.42
# Bi_Male 	StdErr:  6.808 	 YVM:  10.08
# Hawaiian_or_PI 	StdErr:  8.128 	 YVM:  10.243
# Bi_Female 	StdErr:  4.384 	 YVM:  12.06
#
# Potential new issues:
# None

# %% [markdown]
# ### EDA 1.1.2
#
# With both of these metrics largely agreeing about which groups could be potentially underrepresented in the data (and thus be unreliable in our analysis), we can be relatively certain that these groups are too variable to be included. The only demographics in the "Sexual Orientation" category that appear to have adequate representation are Straight, Straight_Male, and Straight_Female. We will have to make a decision about whether to include these after checking our visualization of this category.
#
# Let's take a look at the YVM stats if we drop the variable groups:

# %%
# Create a dictionary of the YVM stats after dropping the "problematic" groups
print(' Statistical breakdown of YVM:')
temp_df = df.drop(watch_these, axis = 1)
yvm_dict = yearly_variance_magnitude(temp_df)

# Code to print them out neatly
print('')
keys = list(yvm_dict.keys())
keys_small = keys[:18]
keys_medium = keys[18:36]
keys_large = keys[36:]
for a, b, c in zip(keys_small, keys_medium, keys_large):
    tab_a = '\t'
    tab_b = '\t'
    tab_c = '\t'
    if len(a) < 7:
        tab_a = '\t\t\t'
    elif len(a) < 14:
        tab_a = '\t\t'
    if len(b) < 6:
        tab_b = '\t\t\t'
    elif len(b) < 14:
        tab_b = '\t\t'
    if len(c) < 6:
        tab_c = '\t\t\t'
    elif len(c) < 14:
        tab_c = '\t\t'
    print(a, tab_a, yvm_dict[a], '\t', b, tab_b, yvm_dict[b], '\t', c, tab_c, yvm_dict[c])
# Out:
#  Statistical breakdown of YVM:
#  Min variance:  0.42
#  Max variance:  2.2
#  Average variance:  0.955
#  Variance range:  1.78
#
# Straight 		 0.42 	 Male 			 0.67 	 55_to_64 		 1.12
# Total 			 0.44 	 Other_House 		 0.67 	 Asian 			 1.16
# Straight_Female 	 0.44 	 Not_Disabled 		 0.686 	 Afr_Amer 		 1.18
# Metro 			 0.45 	 Private_Ins 		 0.7 	 Afr_Amer_not_Hispanic 	 1.24
# In_US 			 0.47 	 Single_Not_Parent 	 0.71 	 Disabled 		 1.357
# Straight_Male 		 0.48 	 18_to_44 		 0.77 	 25_to_44 		 1.37
# Not_Hispanic 		 0.49 	 Widow 			 0.77 	 75_to_84 		 1.38
# White 			 0.5 	 600K_Plus 		 0.78 	 Below_HS 		 1.39
# 65_Plus 		 0.51 	 Two_Adults 		 0.79 	 Below_100K 		 1.41
# Insured 		 0.53 	 45_to_54 		 0.84 	 MA_MS_Plus 		 1.44
# White_not_Hispanic 	 0.55 	 Two_Parent_Family 	 0.84 	 Outside_US 		 1.44
# 45_to_64 		 0.57 	 BA_BS 			 0.88 	 Uninsured 		 1.55
# 400_to_599K 		 0.57 	 Not_Metro 		 0.9 	 Public_Ins 		 1.56
# Married 		 0.57 	 Divorced 		 0.9 	 18_to_24 		 1.61
# ...

# %% [markdown]
# ### EDA 2: Visualizations
#
# The following code graphs line plots for the overall group trend, as well as our major demographic categories. These include gender, race, general age, specific age groups, education, income, household size, birth country, disability, location, insurance, sexual orientation, and marital status.
#
# As a reminder, we found that some race and sexual orientation breakdowns appear problematically variable. Dependent on further analyses, we may consider dropping the Native/Hawaiian, Pacific Islander, or 2 or more race groups. We may consider dropping the sexuality category entirely.

# %% [markdown]
# ### EDA 2.1: Total

# %%
# lineplot of Total Trend
trend_pl = sns.lineplot(data = df['Total'])
trend_pl.set_title('Total Trend', fontsize = 30)
# Out:
# Text(0.5, 1.0, 'Total Trend')

# %% [markdown]
# ### EDA 2.2: Gender

# %%
# lineplot of Gender Breakdown
gender_pl = sns.lineplot(data = gender, dashes = False)

# format title and legend
gender_pl.set_title('Gender', fontsize = 30)
gender_pl.legend(loc = 3, prop = {'size': 17})

# %% [markdown]
# ### EDA 2.3: Race

# %%
# lineplot of race breakdown (all columns)
race_pl_1 = sns.lineplot(data = race, dashes = False)

# format title and legend
race_pl_1.set_title('Race', fontsize = 30)
race_pl_1.legend(loc = 4, prop = {'size': 14}, ncol = 2)

# %% [markdown]
# ### EDA 2.3.1: Race Re-Plot
# We previously identified three potential watch groups here with the Native/Hawaiian, Pacific Islander, or 2 or more race groups, and confirm visually here that said groups each vary wildly. In the following, we regenerate the race lineplot without the three unreliable race breakdowns.

# %%
# remove 'Native', 'Hawaiian or PI', and '2 or more' columns
race = race.drop(['Native', 'Hawaiian_or_PI', '2_or_more'], axis = 1)

# lineplot of race breakdowns (dropped columns)
race_pl_2 = sns.lineplot(data = race, dashes = False)

# format title and legend
race_pl_2.set_title('Race', fontsize = 30)
race_pl_2.legend(loc = 3, prop = {'size': 15}, ncol = 2)

# %% [markdown]
# ### EDA 2.3.2: Race Conclusions
# With those three groups removed, the trends are overall easier to observe. Although it is unclear if the decline is any more dramatic than in other groups, the fact that African Americans (Hispanic or otherwise) are shifted so far down our y-axis is potentially something to keep in mind.

# %% [markdown]
# ### EDA 2.4: Age

# %%
# lineplot of general age breakdown
gAge_pl = sns.lineplot(data = age_general, dashes = False)

# format title and legend
gAge_pl.set_title('General Age', fontsize = 30)
gAge_pl.legend(loc = 3, prop = {'size': 17})

# middle age is on bottom

# %% [markdown]
# ### EDA 2.4.1: Specific Age

# %%
# lineplot of specific age breakdown
sAge_pl = sns.lineplot(data = age_specific, dashes = False)

# format title and legend
sAge_pl.set_title('Specific Age', fontsize = 30)
sAge_pl.legend(loc = 3, prop = {'size': 13}, ncol = 2)

# broken down by common parent/work years

# %% [markdown]
# ### EDA 2.5: Education

# %%
# lineplot of education breakdown
education_pl = sns.lineplot(data = education, dashes = False)

# format title and legend
education_pl.set_title('Education', fontsize = 30)
education_pl.legend(loc = 3, prop = {'size': 17}, ncol = 2)

# %% [markdown]
# ### EDA 2.6: Income

# %%
# lineplot of income breakdown
income_pl = sns.lineplot(data = income, dashes = False)

# format title and legend
income_pl.set_title('Income', fontsize = 30)
income_pl.legend(loc = 3, prop = {'size': 17})

# %% [markdown]
# ### EDA 2.7: Household Size

# %%
# lineplot of household size breakdown
houseSize_pl = sns.lineplot(data = household, dashes = False)

# format title and legend
houseSize_pl.set_title('Household Size', fontsize = 30)
houseSize_pl.legend(loc = 3, prop = {'size': 17}, ncol = 2)

# %% [markdown]
# ### EDA 2.8: Birthplace

# %%
# lineplot of birth country breakdown
birthCountry_pl = sns.lineplot(data = birth_country, dashes = False)

# format title and legend
birthCountry_pl.set_title('Born Inside/Outside US', fontsize = 30)
birthCountry_pl.legend(loc = 3, prop = {'size': 17})

# %% [markdown]
# ### EDA 2.9: Disability Status

# %%
# lineplot of disability breakdown
disability_pl = sns.lineplot(data = disability, dashes = False)

# format title and legend
disability_pl.set_title('Disabled vs Not Disabled', fontsize = 30)
disability_pl.legend(loc = 3, prop = {'size': 15})

# %% [markdown]
# ### EDA 2.10: Location

# %%
# lineplot of location breakdown
location_pl = sns.lineplot(data = location, dashes = False)

# format title and legend
location_pl.set_title('Metro Area vs Not', fontsize = 30)
location_pl.legend(loc = 3, prop = {'size': 17})

# %% [markdown]
# ### EDA 2.11 Insurance Status

# %%
# lineplot of insurance type breakdown
insurance_pl = sns.lineplot(data = insurance, dashes = False)

# format title and legend
insurance_pl.set_title('Insurance Type', fontsize = 30)
insurance_pl.legend(loc = 3, prop = {'size': 17})

# %% [markdown]
# ### EDA 2.12 Marital Status

# %%
# lineplot of marital status breakdown
maritalStatus_pl = sns.lineplot(data = marital_status, dashes = False)

# format title and legend
maritalStatus_pl.set_title('Marital Status', fontsize = 30)
maritalStatus_pl.legend(loc = 3, prop = {'size': 17}, ncol = 2)

# %% [markdown]
# ### EDA 2.13: Sexual Orientation

# %%
# lineplot of sexual orientation (all columns)
sexOrient_pl_1 = sns.lineplot(data = orientation, dashes = False)

# format title and legend
sexOrient_pl_1.set_title('Sexual Orientation', fontsize = 30)
sexOrient_pl_1.legend(loc = 3, prop = {'size': 14}, ncol = 2)

# %% [markdown]
# ### EDA 2.13.1: Orientation Re-plot
# As before, we previously identified potential issues in our analysis of the variability. In this dataset, it appears that the gender distinctions introduce unhelpful amounts of variability that suggests small sample sizes. We should replot this without the gender distinctions to see if the main categories are still viable sources of data.

# %%
# remove columns with large variance
orientation = orientation.drop(['Straight_Male', 
                                'Straight_Female', 
                                'Gay_Male', 
                                'Gay_Female', 
                                'Bi_Male', 
                                'Bi_Female'], axis = 1)

# lineplot of sexual orientation (dropped columns)
sexOrient_pl_2 = sns.lineplot(data = orientation, dashes = False)

# format title and legend
sexOrient_pl_2.set_title('Sexual Orientation', fontsize = 30)
sexOrient_pl_2.legend(loc = 3, prop = {'size': 17})

# %% [markdown]
# ### EDA 2.13.2: Orientation Conclusions
#
# As predicted, these demographic groups are too variable to be reliable in our analysis. With only ~3.5-4% of the population identifying as LGBT [1], we can safely assume that this variability is due to a too-small sample size.
#
# Given that we only have data from 6 of the 11 years that our data span generally, and that only the Straight, Straight_Male, and Straight_Female demographic groups have reliable data even during these years, we are forced to discard sexual orientation as a category for examination.
#
# References:
# 1. Gates, G. (2021, January 14). In U.S., More Adults identifying as LGBT. Retrieved March 04, 2021, from https://news.gallup.com/poll/201731/lgbt-identification-rises.aspx

# %% [markdown]
# # EDA Conclusion
# Now that we've seen the overall trends, we can make some basic predictions. The first thing to notice is that none of the demographic groups (among those we did not reject for excessive variability) showed an overall increase in sufficient sleep over the years. There are many studies that explore the causes behind this trend of worsening sleep [1][2][3], but what we are interested in identifying demographic patterns in our categories. With nearly every group losing sleep, the question we've asked indicates that we should be looking for the greatest loss over time.
#
# References:
# 1. American Psychological Association. (2001, October). Factors that contribute to insomnia. Monitor on Psychology, 32(9). http://www.apa.org/monitor/oct01/insomnia
# 2. Gringras, P., Middleton, B., Skene, D. J., & Revell, V. L. (2015). Bigger, Brighter, Bluer-Better? Current Light-Emitting Devices - Adverse Sleep Properties and Preventative Strategies. Frontiers in public health, 3, 233. https://doi.org/10.3389/fpubh.2015.00233
# 3. Hafner, M., Stepanek, M., Taylor, J., Troxel, W. M., Stolk, C. V. (2017). Why sleep matters - the economic costs of insufficient sleep: A cross-country comparative analysis. Santa Monica, CA: RAND Corporation.

# %%
# Drop problematic groups
to_drop = ['Straight', 'Straight_Male', 'Straight_Female', 'Gay_Les', 'Gay_Male', 'Gay_Female', 
           'Bi', 'Bi_Male', 'Bi_Female', 'Native', 'Hawaiian_or_PI', '2_or_more']
df = df.drop(columns = to_drop)
df.shape
# Out:
# (11, 51)

# %%
# Set our categories, create a dataframe to store our metrics for analysis
demo_type = ['total', 'gender', 'gender',  'race', 'race', 'race', 'race', 'race', 
             'race', 'race', 'age_general', 'age_specific', 'age_specific', 'age_general', 
             'age_specific', 'age_specific', 'age_general', 'age_specific', 'age_specific', 
             'age_specific', 'education', 'education', 'education', 'education', 'education', 
             'education', 'income', 'income', 'income', 'income', 'income', 'household', 
             'household', 'household', 'household', 'household', 'birth_country', 
             'birth_country', 'disability', 'disability', 'location', 'location', 
             'insurance', 'insurance', 'insurance', 'insurance', 'marital_status', 
             'marital_status', 'marital_status', 'marital_status', 'marital_status']
demo_list = df.columns.tolist()
analysis_df = pd.DataFrame(index = demo_list, data = {'demo_type': demo_type, 'demo': demo_list})

# %%
# Calculate the line of best fit to match the line graphs from above
def best_fit_slope(column, df = df):
    x = []
    y = []
    
    for year, item in zip(df.index, df[column]):
        # Filter out nan
        if item > 0:
            x.append(year - 2008)
            y.append(item)
            
    slope, intercept = np.polyfit(x, y, 1)
#     slope = np.round((a * x[2] - a * x[1]) / (x[2] - x[1]), 3)
#     print(x, y, np.round(a, 3))
#     if np.round(a, 3) != slope:
#         print('aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa')
    return np.round(slope, 3)

analysis_df = analysis_df.assign(slope = analysis_df['demo'])
analysis_df['slope'] = analysis_df['slope'].apply(best_fit_slope)
analysis_df.head()
# Out:
#          demo_type      demo  slope
# Total        total     Total -0.502
# Male        gender      Male -0.474
# Female      gender    Female -0.528
# Asian         race     Asian -0.430
# Afr_Amer      race  Afr_Amer -0.583

# %%
# Calculate the total decline: Where each group started subtracted from where they ended
def total_decline(column, df = df):
    
    data = list(filter(lambda item: item > 0, df[column].tolist()))
    
    return data[-1] - data[0]

analysis_df = analysis_df.assign(decline = analysis_df['demo'])
analysis_df['decline'] = analysis_df['decline'].apply(total_decline)
analysis_df.head()
# Out:
#          demo_type      demo  slope  decline
# Total        total     Total -0.502     -4.2
# Male        gender      Male -0.474     -3.9
# Female      gender    Female -0.528     -4.4
# Asian         race     Asian -0.430     -4.4
# Afr_Amer      race  Afr_Amer -0.583     -4.8

# %%
analysis_df.describe()
# Out:
#            slope    decline
# count  51.000000  51.000000
# mean   -0.522824  -4.417647
# std     0.135659   1.301953
# min    -0.918000  -7.200000
# 25%    -0.584000  -4.950000
# 50%    -0.518000  -4.400000
# 75%    -0.458500  -3.900000
# max    -0.228000   0.100000

# %%
sns.regplot(data = analysis_df, x = 'slope', y = 'decline')

# %% [markdown]
# It appears (visually) that slope and decline are linked, but let's do some statistical analysis to be sure.

# %%
outcome, predictors = patsy.dmatrices('decline ~ slope', analysis_df)
mod = sm.OLS(outcome, predictors)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                decline   R-squared:                       0.748
# Model:                            OLS   Adj. R-squared:                  0.743
# Method:                 Least Squares   F-statistic:                     145.2
# Date:                Wed, 10 Mar 2021   Prob (F-statistic):           2.89e-16
# Time:                        18:56:01   Log-Likelihood:                -50.198
# No. Observations:                  51   AIC:                             104.4
# Df Residuals:                      49   BIC:                             108.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0788      0.372     -0.212      0.833      -0.826       0.668
# ...

# %%
analysis_df['slope'].describe()
# Out:
# count    51.000000
# mean     -0.522824
# std       0.135659
# min      -0.918000
# 25%      -0.584000
# 50%      -0.518000
# 75%      -0.458500
# max      -0.228000
# Name: slope, dtype: float64

# %%
# 25% value (based on median) for Slope is -0.584
# Let's create a dataframe that drops everything above that value
slope_df = analysis_df.sort_values(by = 'slope', ascending = False)
drop_list = []
for index, row in slope_df.iterrows():
    if row['slope'] > -0.584:
        drop_list.append(index)
        
slope_df = slope_df.drop(drop_list, axis = 0)

# %%
analysis_df['decline'].describe()
# Out:
# count    51.000000
# mean     -4.417647
# std       1.301953
# min      -7.200000
# 25%      -4.950000
# 50%      -4.400000
# 75%      -3.900000
# max       0.100000
# Name: decline, dtype: float64

# %%
# 25% value for Decline (based on median) is -4.95
# Let's create a dataframe that drops everything above that value
decline_df = analysis_df.sort_values(by = 'decline', ascending = False)

drop_list = []
for index, row in analysis_df.iterrows():
    if row['decline'] > -4.95:
        drop_list.append(index)
        
decline_df = analysis_df.sort_values(by = 'decline', ascending = False).drop(drop_list, axis = 0)

# %%
# Find the values in the worst 25% of both slope and decline
both = []
for slope in slope_df.index.tolist():
    if slope in decline_df.index.tolist():
        both.append(slope)

# Create new dataframes with just the values in this list
    # Sidenote: I've never actually written single line for loops with conditionals before, and this was kinda cool lol
worst_sleepers_analysis = analysis_df.drop(labels = [i for i in analysis_df.index if (i not in both)], axis = 0)
worst_sleepers_df = df.drop(labels = [i for i in analysis_df.index if (i not in both)], axis = 1)
worst_sleepers_analysis.sort_values(by = ['demo_type', 'decline'])
# Out:
#                       demo_type               demo  slope  decline
# 45_to_64            age_general           45_to_64 -0.585     -5.3
# 55_to_64           age_specific           55_to_64 -0.714     -6.6
# 25_to_44           age_specific           25_to_44 -0.642     -5.3
# Some_college          education       Some_college -0.632     -6.6
# MA_MS_Plus            education         MA_MS_Plus -0.614     -5.6
# Single_Parent         household      Single_Parent -0.918     -7.2
# Two_Parent_Family     household  Two_Parent_Family -0.717     -5.8
# Below_100K               income         Below_100K -0.735     -6.7
# 100_to_199K              income        100_to_199K -0.764     -6.0
# Public_Ins            insurance         Public_Ins -0.651     -5.0
# Hispanic                   race           Hispanic -0.790     -6.4

# %%
# This function is to help decide which metric to use to calculate "winners"
def slope_or_decline(df = worst_sleepers_analysis, stats_df = analysis_df):
    # Calculate the standard deviation of all slopes and declines
    slope_std = stats_df['slope'].agg('std')
    decline_std = stats_df['decline'].agg('std')
    
    # These are the demographic groups we need to check
    demo_check_list = ['education', 'age_specific', 'income', 'household']
    out_dict = {}
    for demo in demo_check_list:
        # Create a slice of df for only the current demographic group
        temp_df = df[df['demo_type'] == demo]
        
        # Get lists of the slopes and declines, each with 2 values
        slopes = temp_df['slope'].tolist()
        declines = temp_df['decline'].tolist()
        
        # Divide the difference of the slopes and declines by the appropriate std values
        slope_dif = (abs(slopes[0] - slopes[1]) / slope_std)
        decline_dif = (abs(declines[0] - declines[1]) / decline_std)
        
        # Add our decision to the dictionary
        if slope_dif == decline_dif:
            out_dict[demo] = 'Hung Jury'
        elif slope_dif > decline_dif:
            out_dict[demo] = 'Slope'
        else:
            out_dict[demo] = 'Decline'
            
            
    return(out_dict)
slope_or_decline()
# Out:
# {'education': 'Decline',
#  'age_specific': 'Decline',
#  'income': 'Decline',
#  'household': 'Slope'}

# %% [markdown]
# As it happens, the same demographic wins by either metric in the "household" category, so going by this, it seems that "Decline" should be our primary metric for concluding which demographic gets the title of "worst" in each category. It is also worth noting that the "worst" narrow age group falls within the range of the "worst" broad age group, and has both a larger decline and a steeper slope, so the broad age group has been omitted in favor of the narrow one.
#
# Going by this, the worst sleepers in each demographic category are:
#
# * Age: 55-64
# * Education: Some College
# * Household: Single Parent
# * Income: Below 100K USD
# * Insurance: Public Insurance
# * Race: Hispanic

# %%
# List of the "losing" demographics; drop from both dataframes
to_drop = ['45_to_64', '25_to_44', 'MA_MS_Plus', '100_to_199K', 'Two_Parent_Family']
worst_sleepers_analysis = worst_sleepers_analysis.drop(labels = to_drop, axis = 0).sort_values(by = 'demo_type')
worst_sleepers_df = worst_sleepers_df.drop(columns = to_drop)

# Add back the total trend for comparison
worst_sleepers_analysis = worst_sleepers_analysis.append(analysis_df.loc['Total'])
worst_sleepers_df['Total'] = df['Total']

# # While we're at it, we need to start caring about colors. Let's create our color pallete
colors = {'55_to_64': 'purple', 'Some_college': 'blue', 'Single_Parent': 'green', 
          'Below_100K': 'yellow', 'Public_Ins': 'orange', 'Hispanic': 'red', 'Total': 'black'}

# %%
worst_pl_1 = sns.lineplot(data = worst_sleepers_df, dashes = False, palette = colors)

# format title and legend
worst_pl_1.set_title('Worst Sleepers Over Time', fontsize = 30)
worst_pl_1.legend(loc = 3, prop = {'size': 14})

# %%
worst_bar_slope = sns.barplot(data = worst_sleepers_analysis.sort_values(by = 'slope'), 
                              x = 'demo', y = 'slope', palette = colors)

# format title and legend
worst_bar_slope.set_title('Worst Sleepers by Slope (Predicted Sleep Loss Over Time)', fontsize = 30)
# Out:
# Text(0.5, 1.0, 'Worst Sleepers by Slope (Predicted Sleep Loss Over Time)')

# %%
worst_bar_decline = sns.barplot(data = worst_sleepers_analysis.sort_values(by = 'decline'), 
                                x = 'demo', y = 'decline', palette = colors)

# format title and legend
worst_bar_decline.set_title('Worst Sleepers by Total Decline 2008–2018 ', fontsize = 30)
# Out:
# Text(0.5, 1.0, 'Worst Sleepers by Total Decline 2008–2018 ')

# %% [markdown]
# Individually, each demographic we identified as having the largest declines in sleep quality can be confirmed by current evidence. Compared with Blacks, Asians, and Whites, Hispanics report the highest percentage of inability to get enough sleep due to their weekday routine [3]. In addition, 55–64-year-olds are 26 percent more likely to report their sleep as fair to poor compared with 65–84-year-olds, and are most likely to report (71 percent) a sleep problem [2]. Finally, single parents, our category with the most stark decline, are more likely to experience lower sleep quality (42.6 percent) compared with adults in two-parent households (32.7 percent), and adults living without children (31.0 percent) [4].
#
# However, it is important we note that our categories are not mutually exclusive; a person can fall into several of the demographic categories with the highest decline in sleep quality. Indeed, there are established relationships between several of our demographics: individuals with public insurance (e.g., Medicaid) by definition earn less than $100k per year; lesser education (e.g., "Some College") is a predictor of lower income; and single parents not only lack a second breadwinner, but must pay the costs of raising a child. Furthermore, ethnic minorities, such as Hispanics, suffer vast prejudice in the healthcare sector, aptly demonstrated by one Colorado study reporting Hispanics making up 62.1 percent of hospitalizations and 51.2 percent of deaths from the SARS-CoV-2 pandemic [6]. Perhaps the only demographic in our conclusions with no intrinsic relationship to our other categories is age.
#
# In the present study, we rejected the null hypothesis for two of our five predictions (i.e., the medically underserved; low socioeconomic status (SES)), and failed to reject the null for the remaining three (i.e., younger age groups; women; and people living in metropolitan areas). Although we found evidence that overlaps with the latter three groups, considering them would only be speculatory. For example, a subset of the "Some College" group consists of currently studying individuals, which may be interpreted in support of our hypothesis that young people are losing sleep. In addition, the majority of single parents (80 percent) are single mothers [7] which may be interpreted as women losing sleep. Notwithstanding, we did not identify as individual categories women or young people (sleep quality in 18–24-year-olds marginally improved) qualifying as "worst sleepers".
#
# Taken together, the importance of our findings lies largely in future directions, furthering improvements and research into sleep quality, emphasizing our disproportionately disaffected demographics: low SES (i.e. low income; some college; publicly insured), as well as, Hispanics (ethnic minorities, generally), older adults, and households with single parents.
#
# Limitations in the present study consist the Center for Disease Control's definition of optimal sleep quality as sleep duration. While sleep quality is indeed contingent on sleep duration, defining solely as such potentially overlooks sleep sufficiency, as well as factors such as disruption and biological/psychological constraints on sleep [1]. Furthermore,
#
#
# References:
# 1. Ferrara, M., & De Gennaro, L. (2001). How much sleep do we need?. Sleep medicine reviews, 5(2), 155–179. https://doi.org/10.1053/smrv.2000.0138
# 2. National Institute of Neurological Disorders and Stroke. (n.d.). Brain basics: Understanding sleep. Retrieved March 04, 2021, from https://www.ninds.nih.gov/Disorders/Patient-Caregiver-Education/Understanding-Sleep
# 2. National Sleep Foundation. (2003). Sleep in America Poll: Sleep and Aging. https://www.sleepfoundation.org/wp-content/uploads/2018/10/2003SleepPollExecSumm.pdf?x96585
# 3. National Sleep Foundation. (2010). Sleep in America Poll: Sleep and Ethnicity. https://www.sleepfoundation.org/wp-content/uploads/2018/10/NSF-Sleep-in-America-Poll-Summary-of-Findings-.pdf?x96585
# 4. Nugent, C. N., & Black, L. I. (2016). Sleep Duration, Quality of Sleep, and Use of Sleep Medication, by Sex and Family Type, 2013-2014. NCHS Data Brief. https://www.cdc.gov/nchs/products/databriefs/db230.htm
# 5. Hafner, M., Stepanek, M., Taylor, J., Troxel, W. M., Stolk, C. V. (2017). Why sleep matters - the economic costs of insufficient sleep: A cross-country comparative analysis. Santa Monica, CA: RAND Corporation.
# 6. Podewils, L. J., Burket, T. L., Mettenbrink, C., Steiner, A., Seidel, A., Scott, K., Cervantes, L., & Hasnain-Wynia, R. (2020). Disproportionate Incidence of COVID-19 Infection, Hospitalizations, and Deaths Among Persons Identifying as Hispanic or Latino - Denver, Colorado March-October 2020. MMWR. Morbidity and mortality weekly report, 69(48), 1812–1816. https://doi.org/10.15585/mmwr.mm6948a3
# 7. U.S. Census Bureau. (2019). Table FG6. One-parent Unmarried Family Groups with Own Children Under 18, by Marital Status of the Reference Person: 2019. https://www.census.gov/data/tables/2019/demo/families/cps-2019.html
